# %%
class Tienda_online:
    def __init__(self):
        self.inventario=[]

    def agregar_producto(self,nombre,precio,cantidad):
        for producto in self.inventario:
           if producto["nombre"] == nombre:
            producto["cantidad"] = producto["cantidad"] + cantidad
            return
        producto_nuevo = {
        "nombre": nombre,
        "precio": precio,
        "cantidad": cantidad
    }
    
        self.inventario.append(producto_nuevo)

    def informacion_inventario(self):
         for producto in self.inventario:
          print(producto["nombre"],
                producto["precio"],
                producto["cantidad"])
          
    def buscar_producto(self,nombre):
       for producto in self.inventario:
          if producto["nombre"]==nombre:
             print("pantalon:",producto)
             return producto
          
    def actualizar_stock(self,nombre,cantidad):
       for producto in self.inventario:
           if producto["nombre"] == nombre:
              producto["cantidad"] = producto["cantidad"] + cantidad
              return

# %%
tienda1=Tienda_online()
tienda1.agregar_producto("camisa",15,5)
tienda1.agregar_producto("top",20,3)
tienda1.agregar_producto("camisa",15,2)
tienda1.agregar_producto("pantalon",25,8)
tienda1.informacion_inventario()
# Out:
# camisa 15 7
# top 20 3
# pantalon 25 8

# %%
busqueda=tienda1.buscar_producto("top")
busqueda=tienda1.buscar_producto("pantalon")
# Out:
# pantalon: {'nombre': 'top', 'precio': 20, 'cantidad': 3}
# pantalon: {'nombre': 'pantalon', 'precio': 25, 'cantidad': 8}
