# %%
class Tienda_online:
    def __init__(self):
        self.inventario=[]

    def agregar_producto(self,nombre,precio,cantidad):
        for producto in self.inventario:
           if producto["nombre"] == nombre:
            producto["cantidad"] = producto["cantidad"] + cantidad
            return
        producto_nuevo = {
        "nombre": nombre,
        "precio": precio,
        "cantidad": cantidad
    }
    
        self.inventario.append(producto_nuevo)

    def informacion_inventario(self):
         for producto in self.inventario:
          print(producto["nombre"],
                producto["precio"],
                producto["cantidad"])
          
    def buscar_producto(self,nombre):
       for producto in self.inventario:
          if producto["nombre"]==nombre:
      
             return producto
          
    def actualizar_stock(self,nombre,cantidad):
       for producto in self.inventario:
           if producto["nombre"] == nombre:
              producto["cantidad"] = producto["cantidad"] + cantidad
              return 
           print("producto no encontrado")

    def eliminar_producto(self,nombre):
       for producto in self.inventario:
          if producto["nombre"] == nombre:
            self.inventario.remove(producto)
            return 
            print("producto no encontrado")
    def valor_inventario(self):
       total=0
       for producto in self.inventario:
          total=total+(producto["precio"]*producto["cantidad"])
          return total

# %%
tienda1=Tienda_online()
tienda1.agregar_producto("camisa",15,5)
tienda1.agregar_producto("top",20,3)
tienda1.agregar_producto("camisa",15,2)
tienda1.agregar_producto("pantalon",25,8)
tienda1.agregar_producto("pantalon",25,8)
tienda1.agregar_producto("bikini",12,8)
tienda1.agregar_producto("chaqueta",90,2)

# %%
busqueda=tienda1.buscar_producto("chaqueta")
print(busqueda)
# Out:
# {'nombre': 'chaqueta', 'precio': 90, 'cantidad': 2}

# %%
tienda1.informacion_inventario()
# Out:
# camisa 15 7
# top 20 3
# pantalon 25 16
# bikini 12 8
# chaqueta 90 2

# %%
actualizar_stock=tienda1.actualizar_stock("camisa",5,)

# %%
tienda1.informacion_inventario()
# Out:
# camisa 15 12
# top 20 3
# pantalon 25 16
# bikini 12 8
# chaqueta 90 2

# %%
valor=tienda1.valor_inventario()
print(valor)
# Out:
# 180
